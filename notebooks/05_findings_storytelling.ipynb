# %% [markdown]
# # 05 — Findings & Storytelling
#
# Telecom Customer Churn — Stage 1 scaffold notebook.

# %% [markdown]
# ## Objective
#
# Synthesize results into a narrative: headline churn metrics, the strongest drivers, revenue-at-risk story, and recommended interventions. Feed the Tableau spec / dashboard wireframes.
#
# **Inputs:** Outputs of notebooks 01–04 (data/processed/ + reports/)
#
# **Outputs:** reports/insights/ + reports/tableau/ dashboard spec
