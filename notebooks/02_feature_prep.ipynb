# %% [markdown]
# # 02 — Feature Preparation
#
# Telecom Customer Churn — Stage 1 scaffold notebook.

# %% [markdown]
# ## Objective
#
# Engineer analysis-ready features: tenure_bin, contract_commitment, bundle_count, and is_fiber; one-hot/encode categoricals; scale numeric columns. Align with sql/transformations/020_feature_engineering.sql.
#
# **Inputs:** data/interim/clean_typed.csv
#
# **Outputs:** data/processed/analysis_ready.csv
